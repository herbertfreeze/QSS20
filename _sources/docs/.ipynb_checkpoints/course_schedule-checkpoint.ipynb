# %% [markdown]
# # Course Schedule
#
# The course will meet on Tuesdays and Thursdays from 10:10 AM to 12:00 PM EST.
#
# Here is the current week-by-week schedule 📅 . We may adjust as we go along.
#
# To get started, let's create the course schedule using the pandas module in Python. **Click "show" to see the underlying code!**

# %%
# import modules
import pandas as pd
import re
import numpy as np


# tell python to display output and print multiple objects
from IPython.display import display, HTML
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# create range b/t start and end date of course
start_date = pd.to_datetime("2025-04-01")
end_date = pd.to_datetime("2025-06-04")
alldates = pd.date_range(start_date, end_date)

# subset to days in that range equal to Tuesday and Thursday
tt = alldates[alldates.day_name().isin(['Tuesday', 'Thursday']) ]

# create DataFrame with that information
qss20_dates = [re.sub("2025\\-", "", str(day.date())) for day in tt]
course_sched = pd.DataFrame({'dow': tt.day_name(),
                             'date': qss20_dates})
course_sched['day_date'] = course_sched.dow.astype(str) + " " + \
            course_sched.date.astype(str)

# display the resulting date sequence
display(course_sched.day_date)
# Out:
# 0      Tuesday 04-01
# 1     Thursday 04-03
# 2      Tuesday 04-08
# 3     Thursday 04-10
# 4      Tuesday 04-15
# 5     Thursday 04-17
# 6      Tuesday 04-22
# 7     Thursday 04-24
# 8      Tuesday 04-29
# 9     Thursday 05-01
# 10     Tuesday 05-06
# 11    Thursday 05-08
# 12     Tuesday 05-13
# 13    Thursday 05-15
# 14     Tuesday 05-20
# 15    Thursday 05-22
# 16     Tuesday 05-27
# 17    Thursday 05-29
# 18     Tuesday 06-03
# Name: day_date, dtype: object

# %% [markdown]
# The next few blocks of code creates the actual schedule content by creating a new column.

# %%
# create basic schedule content

# list of concepts
concepts = ["Course intro. & syllabus review",
            "No Class (@Conference)",
            "Python basics (variables, lists, arrays) & software setup",
            "Pandas for data manipulation 1 + static data visualization",
            "Pandas 2 (X-hour)",
            "User-defined functions",
            "Workflow basics: command line & Github",
            "Merging data",
            "Regular expressions (Regex)",
            "Text-as-data 1 (text mining)",
            "Text-as-data 2 (topic modeling)",
            "APIs",
            "Social Network Visualization",
            "Green Key Weekend (let's be real)",
            "Supervised machine learning 1",
            "Supervised machine learning 2",
            "SQL",
            "Common Distribs; Project work session",
            "Final presentations"]

# check that concepts match number of weeks
assert len(course_sched.day_date) == len(concepts)

# combine dates with concepts
course_sched_concepts = pd.DataFrame({'Date': course_sched.day_date,
                                     'Concepts': concepts})

df = course_sched_concepts.copy()

print(df)
# Out:
#               Date                                           Concepts
# 0    Tuesday 04-01                    Course intro. & syllabus review
# 1   Thursday 04-03                             No Class (@Conference)
# 2    Tuesday 04-08  Python basics (variables, lists, arrays) & sof...
# 3   Thursday 04-10  Pandas for data manipulation 1 + static data v...
# 4    Tuesday 04-15                                  Pandas 2 (X-hour)
# 5   Thursday 04-17                             User-defined functions
# 6    Tuesday 04-22             Workflow basics: command line & Github
# 7   Thursday 04-24                                       Merging data
# 8    Tuesday 04-29                        Regular expressions (Regex)
# 9   Thursday 05-01                       Text-as-data 1 (text mining)
# 10   Tuesday 05-06                    Text-as-data 2 (topic modeling)
# 11  Thursday 05-08                                               APIs
# 12   Tuesday 05-13                       Social Network Visualization
# 13  Thursday 05-15                  Green Key Weekend (let's be real)
# 14   Tuesday 05-20                      Supervised machine learning 1
# 15  Thursday 05-22                      Supervised machine learning 2
# 16   Tuesday 05-27                                                SQL
# 17  Thursday 05-29              Common Distribs; Project work session
# 18   Tuesday 06-03                                Final presentations

# %%
# define DataCamp modules
modules = ["",
           "Intro. to Python (chpts. 2-3)",
           "Data Manipulation with pandas (course)","","",
           "Writing your own functions (chpt.)",
           "Intro. to Shell, Intro. to GitHub (chpts.)",
           "Joining Data with pandas (chpts. 1-2)","",
           "Regular Expressions for Pattern Matching (chpt.)",
           "Text preprocessing, POS tagging and NER (chpt.)",
           
           "",
           "","",
           "Supervised Learning with scikit-learn (course)",
           "",
           "Intro. to SQL (chpts. 1-2)",
          "",""]

df["DataCamp module(s) (if any)"] = modules

# %%
# define assignments
assignments = ["First Latex Submission (solo, due Sunday 04-06)", "",
               "Problem set one (submit as group; due Monday 04-18)","","",
               "Final Project Form (due Thursday 04-28)",
               "Problem set two (due Monday 04-28)","",
               "Final project milestone 1 (due Wednesday 05-14)","",
               "Problem set three (due Wednesday 05-14)","",
               "Final project milestone 2 (due Thursday 05-26) ","",
               "Problem set four (due Friday 05-26)","","","",
               "Final project presentation (paper due Tuesday 06-09)"]

df["Due (11:59 PM EST unless otherwise specified)"] = assignments

# %%
HTML(df.to_html(index=False, escape = False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Date</th>
#       <th>Concepts</th>
#       <th>DataCamp module(s) (if any)</th>
#       <th>Due (11:59 PM EST unless otherwise specified)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Tuesday 04-01</td>
#       <td>Course intro. & syllabus review</td>
#       <td></td>
#       <td>First Latex Submission (solo, due Sunday 04-06)</td>
#     </tr>
#     <tr>
#       <td>Thursday 04-03</td>
#       <td>No Class (@Conference)</td>
#       <td>Intro. to Python (chpts. 2-3)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Tuesday 04-08</td>
#       <td>Python basics (variables, lists, arrays) & software setup</td>
#       <td>Data Manipulation with pandas (course)</td>
#       <td>Problem set one (submit as group; due Monday 04-18)</td>
#     </tr>
#     <tr>
#       <td>Thursday 04-10</td>
#       <td>Pandas for data manipulation 1 + static data visualization</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Tuesday 04-15</td>
#       <td>Pandas 2 (X-hour)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Thursday 04-17</td>
#       <td>User-defined functions</td>
#       <td>Writing your own functions (chpt.)</td>
#       <td>Final Project Form (due Thursday 04-28)</td>
#     </tr>
#     <tr>
#       <td>Tuesday 04-22</td>
#       <td>Workflow basics: command line & Github</td>
#       <td>Intro. to Shell, Intro. to GitHub (chpts.)</td>
#       <td>Problem set two (due Monday 04-28)</td>
#     </tr>
#     <tr>
#       <td>Thursday 04-24</td>
#       <td>Merging data</td>
#       <td>Joining Data with pandas (chpts. 1-2)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Tuesday 04-29</td>
#       <td>Regular expressions (Regex)</td>
#       <td></td>
#       <td>Final project milestone 1 (due Wednesday 05-14)</td>
#     </tr>
#     <tr>
#       <td>Thursday 05-01</td>
#       <td>Text-as-data 1 (text mining)</td>
#       <td>Regular Expressions for Pattern Matching (chpt.)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Tuesday 05-06</td>
#       <td>Text-as-data 2 (topic modeling)</td>
#       <td>Text preprocessing, POS tagging and NER (chpt.)</td>
#       <td>Problem set three (due Wednesday 05-14)</td>
#     </tr>
#     <tr>
#       <td>Thursday 05-08</td>
#       <td>APIs</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Tuesday 05-13</td>
#       <td>Social Network Visualization</td>
#       <td></td>
#       <td>Final project milestone 2 (due Thursday 05-26)</td>
#     </tr>
#     <tr>
#       <td>Thursday 05-15</td>
#       <td>Green Key Weekend (let's be real)</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Tuesday 05-20</td>
#       <td>Supervised machine learning 1</td>
#       <td>Supervised Learning with scikit-learn (course)</td>
#       <td>Problem set four (due Friday 05-26)</td>
#     </tr>
#     <tr>
#       <td>Thursday 05-22</td>
#       <td>Supervised machine learning 2</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Tuesday 05-27</td>
#       <td>SQL</td>
#       <td>Intro. to SQL (chpts. 1-2)</td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Thursday 05-29</td>
#       <td>Common Distribs; Project work session</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <td>Tuesday 06-03</td>
#       <td>Final presentations</td>
#       <td></td>
#       <td>Final project presentation (paper due Tuesday 06-09)</td>
#     </tr>
#   </tbody>
# </table>
