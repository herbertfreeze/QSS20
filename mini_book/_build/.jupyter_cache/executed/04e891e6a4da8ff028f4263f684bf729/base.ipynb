# %%
## import modules
import pandas as pd

from IPython.display import display, HTML

grade_summary = pd.DataFrame({'Assignments':
                ["Quizzes (5, drop lowest)",
                  "Exam 1",
                  "Exam 2 (Agentic)",
                  "Me Search",
                  "NotebookLM lit review",
                  "Initial data analysis",
                  "Milestone 2 (team, post-merge)",
                  "Final deliverables (presentation + paper + repo + transparency report)"],
                'Percentage':
                [10, 
                 5,
                 10,
                 10,
                 10,
                 15,
                 5,
                 35],
                             }) 

HTML(grade_summary.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Assignments</th>
#       <th>Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Quizzes (5, drop lowest)</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <td>Exam 1</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>Exam 2 (Agentic)</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <td>Me Search</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <td>NotebookLM lit review</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <td>Initial data analysis</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <td>Milestone 2 (team, post-merge)</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>Final deliverables (presentation + paper + repo + transparency report)</td>
#       <td>35</td>
#     </tr>
#   </tbody>
# </table>
